# %% [markdown]
# **Made by CawaTech**
# posted on github
#
# --------------------
#
# **Data by EMMANUEL F. WERR on kaggle**
# https://www.kaggle.com/datasets/emmanuelfwerr/london-weather-data

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy

# %%
df = pd.read_csv("london_weather.csv") # reading in csv data
print(df.shape)
df # giving out data
# Out:
# (15341, 10)
#            date  cloud_cover  sunshine  global_radiation  max_temp  mean_temp  \
# 0      19790101          2.0       7.0              52.0       2.3       -4.1
# 1      19790102          6.0       1.7              27.0       1.6       -2.6
# 2      19790103          5.0       0.0              13.0       1.3       -2.8
# 3      19790104          8.0       0.0              13.0      -0.3       -2.6
# 4      19790105          6.0       2.0              29.0       5.6       -0.8
# ...         ...          ...       ...               ...       ...        ...
# 15336  20201227          1.0       0.9              32.0       7.5        7.5
# 15337  20201228          7.0       3.7              38.0       3.6        1.1
# 15338  20201229          7.0       0.0              21.0       4.1        2.6
# 15339  20201230          6.0       0.4              22.0       5.6        2.7
# 15340  20201231          7.0       1.3              34.0       1.5       -0.8
#
# ...

# %%
print("Cloud cover mid:      ", round(numpy.mean(df.cloud_cover),2))
print("sunshine mid:         ", round(numpy.mean(df.sunshine),2))
print("global radiation mid: ", round(numpy.mean(df.global_radiation),2))
print("max temp mid:         ", round(numpy.mean(df.max_temp),2))
print("mean temp mid:        ", round(numpy.mean(df.mean_temp),2))
print("mix temp mid:         ", round(numpy.mean(df.min_temp),2))
print("precipitation mid:    ", round(numpy.mean(df.precipitation),2))
print("Pressure mid:         ", round(numpy.mean(df.pressure),2))
print("snow_depth mid:       ", round(numpy.mean(df.snow_depth),2))
# Out:
# Cloud cover mid:       5.27
# sunshine mid:          4.35
# global radiation mid:  118.76
# max temp mid:          15.39
# mean temp mid:         11.48
# mix temp mid:          7.56
# precipitation mid:     1.67
# Pressure mid:          101536.61
# snow_depth mid:        0.04

# %%
sunshine: pd.DataFrame = df.iloc[:,2]
precipatition: pd.DataFrame = df.iloc[:,7]

precipatition.plot(figsize = (30, 18),
              grid=True,
              )
# Out:
# <AxesSubplot: >

# %%
# we saw the shape of the diagramm so lets try to do it as an histogram
precipatition.hist() # this makes more sence
sunshine.std()
# Out:
# 4.0283394046795955

# %%
ax = df['cloud_cover'].value_counts().plot(kind='pie')
ax.set_title('cloud cover')
# Out:
# Text(0.5, 1.0, 'sunshine')
